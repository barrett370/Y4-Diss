# %%
include("parallelCGA.jl")
include("plottingUtils.jl")
# Out:
# plot_generation_gif (generic function with 1 method)

# %% [markdown]
# # Building *realistic* road layout with *realistic* routes

# %%
boundary1(x) = 0
boundary2(x) = 12

obs = [
    Rectangle(6,1,Point(2.5,2.5))
    
    Circle(1,Point(7.5,1))
Circle(1,Point(8.5,1))
Circle(1,Point(9.5,1))
Circle(1,Point(10.5,1))
]

road = Road(boundary1, boundary2, obs)
# Out:
# Road(boundary1, boundary2, Obstacle[Rectangle(6, 1, Point(2.5, 2.5)), Circle(1, Point(7.5, 1)), Circle(1, Point(8.5, 1)), Circle(1, Point(9.5, 1)), Circle(1, Point(10.5, 1))])

# %%
draw_road(road,0,14)

# %%
# Out:
# 4-element Array{Point,1}:
#  Point(12.5, 10)
#  Point(12.5, 3)
#  Point(10, 7.5)
#  Point(12.5, 7.5)

# %%
P = PCGA(starts,goals,road,2,6)
# Out:
# UndefVarError: starts not defined
#
# Stacktrace:
#  [1] top-level scope at In[22]:1

# %%
P
# Out:
# 4-element Array{Individual,1}:
#  Individual(Phenotype(Point(0, 7.5), Point[Point(0, 7.5), Point(0.5042764851779069, 8.496524200044107), Point(1.0721531865092115, 8.538770861983899), Point(3.6833333333333336, 7.5), Point(12.5, 10)], Point(12.5, 10)), 60.992476250304136)
#  Individual(Phenotype(Point(0, 2.5), Point[Point(0, 2.5), Point(8.99709246853502, 2.9299909484153215), Point(12.5, 3)], Point(12.5, 3)), 15.364411984225613)
#  Individual(Phenotype(Point(2.5, 2.5), Point[Point(2.5, 2.5), Point(8.21201618974913, 7.336590355131461), Point(10, 7.5)], Point(10, 7.5)), 14.09185997604025)
#  Individual(Phenotype(Point(5, 5), Point[Point(5, 5), Point(5.583975131916683, 8.830045080332324), Point(6.66875, 4.85), Point(7.2375, 4.8999999999999995), Point(11.79898563328793, 5.180368158387169), Point(12.5, 7.5)], Point(12.5, 7.5)), 66.87891190470054)

# %%
plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/jIs2V/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
infeasible_distance(road,P[1].phenotype.genotype)
# Out:
# 3.754424740063113

# %%
P =[ Individual(Phenotype(Point(0, 7.5), Point[Point(0, 7.5), Point(7.125, 7.25), Point(12.5, 10)], Point(12.5, 10)), 56.959375393236584)
 Individual(Phenotype(Point(0, 2.5), Point[Point(0, 2.5), Point(2.7625, 2.45), Point(8.425, 2.5), Point(12.5, 3)], Point(12.5, 3)), 12.522738472466298)
 Individual(Phenotype(Point(2.5, 2.5), Point[Point(2.5, 2.5), Point(3.46875, 2.0), Point(8.782092496222393, 6.018215138296851), Point(10, 7.5)], Point(10, 7.5)), 9.49070370304603)
 Individual(Phenotype(Point(5, 5), Point[Point(5, 5), Point(8.375, 4.85), Point(12.5, 7.5)], Point(12.5, 7.5)), 8.09344744864917)
]
# Out:
# 4-element Array{Individual,1}:
#  Individual(Phenotype(Point(0, 7.5), Point[Point(0, 7.5), Point(7.125, 7.25), Point(12.5, 10)], Point(12.5, 10)), 56.959375393236584)
#  Individual(Phenotype(Point(0, 2.5), Point[Point(0, 2.5), Point(2.7625, 2.45), Point(8.425, 2.5), Point(12.5, 3)], Point(12.5, 3)), 12.522738472466298)
#  Individual(Phenotype(Point(2.5, 2.5), Point[Point(2.5, 2.5), Point(3.46875, 2.0), Point(8.782092496222393, 6.018215138296851), Point(10, 7.5)], Point(10, 7.5)), 9.49070370304603)
#  Individual(Phenotype(Point(5, 5), Point[Point(5, 5), Point(8.375, 4.85), Point(12.5, 7.5)], Point(12.5, 7.5)), 8.09344744864917)

# %%
P[1].fitness
# Out:
# 56.959375393236584

# %%
include("plottingUtils.jl")
plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/jIs2V/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
P = [ Individual(Phenotype(Point(0, 7.5), Point[Point(0, 7.5), Point(3.1416666666666666, 7.800000000000001), Point(5.1625, 7.550000000000001), Point(6.083333333333333, 7.500000000000001), Point(6.604166666666666, 7.450000000000001), Point(8.253079221793106, 16.38007753907104), Point(8.424999999999999, 7.600000000000001), Point(12.5, 10)], Point(12.5, 10)), 63.16266920906128)
 Individual(Phenotype(Point(0, 2.5), Point[Point(0, 2.5), Point(2.125, 2.45), Point(3.65, 2.5), Point(4.675, 2.55), Point(6.1, 2.5999999999999996), Point(7.0249999999999995, 2.6499999999999995), Point(12.5, 3)], Point(12.5, 3)), 12.514521118776495)
 Individual(Phenotype(Point(2.5, 2.5), Point[Point(2.5, 2.5), Point(2.9125, 2.3), Point(3.925, 2.5), Point(4.8374999999999995, 2.7), Point(5.6499999999999995, 3.2), Point(6.862499999999999, 2.8000000000000003), Point(7.374999999999999, 3.1), Point(10, 7.5)], Point(10, 7.5)), 10.235176704326967)
 Individual(Phenotype(Point(5, 5), Point[Point(5, 5), Point(8.875, 5.15), Point(12.5, 7.5)], Point(12.5, 7.5)), 8.05184010034339)
]
# Out:
# 4-element Array{Individual,1}:
#  Individual(Phenotype(Point(0, 7.5), Point[Point(0, 7.5), Point(3.1416666666666666, 7.800000000000001), Point(5.1625, 7.550000000000001), Point(6.083333333333333, 7.500000000000001), Point(6.604166666666666, 7.450000000000001), Point(8.253079221793106, 16.38007753907104), Point(8.424999999999999, 7.600000000000001), Point(12.5, 10)], Point(12.5, 10)), 63.16266920906128)
#  Individual(Phenotype(Point(0, 2.5), Point[Point(0, 2.5), Point(2.125, 2.45), Point(3.65, 2.5), Point(4.675, 2.55), Point(6.1, 2.5999999999999996), Point(7.0249999999999995, 2.6499999999999995), Point(12.5, 3)], Point(12.5, 3)), 12.514521118776495)
#  Individual(Phenotype(Point(2.5, 2.5), Point[Point(2.5, 2.5), Point(2.9125, 2.3), Point(3.925, 2.5), Point(4.8374999999999995, 2.7), Point(5.6499999999999995, 3.2), Point(6.862499999999999, 2.8000000000000003), Point(7.374999999999999, 3.1), Point(10, 7.5)], Point(10, 7.5)), 10.235176704326967)
# ...

# %%
P[1].fitness
# Out:
# 63.16266920906128

# %%
include("plottingUtils.jl")
plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/jIs2V/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
collisionDetection(P[2].phenotype.genotype, P[3].phenotype.genotype)
# Out:
# "Detecting Collisions parallel" = "Detecting Collisions parallel"
# Found intersection (true, (Point[Point(4.79921875, 2.5562499999999995), Point(4.4527343749999995, 2.5421875), Point(4.115429687499999, 2.5296874999999996), Point(3.777246093749999, 2.5183593749999997), Point(3.4312011718749993, 2.5082031249999996), Point(3.0708740234375, 2.49951171875), Point(2.6904174804687497, 2.4928710937500003)], Point[Point(2.5, 2.5), Point(2.603125, 2.45), Point(2.74375, 2.425), Point(2.9109375, 2.4187499999999997), Point(3.096484375, 2.427734375), Point(3.2947265625, 2.4490234375), Point(3.5018798828125, 2.4797119140625), Point(3.7154975891113287, 2.51722412109375)]))
# closed
# Intersection
# abs(bezLength(c1_to_intersect) - bezLength(c2_to_intersect)) < 3.5 = false
# false

# %%
P = [Individual(Phenotype(Point(0, 7.5), Point[Point(0, 7.5), Point(2.2416666666666667, 7.433333333333334), Point(2.7625, 7.4), Point(3.2833333333333337, 7.5), Point(4.204166666666667, 7.333333333333333), Point(5.825, 7.3), Point(10.538890680627116, 19.364065470035655), Point(12.5, 10)], Point(12.5, 10)), 70.37475581977573)
 Individual(Phenotype(Point(0, 2.5), Point[Point(0, 2.5), Point(8.125, 2.5), Point(10.080648092947305, 2.5989547397963246), Point(12.5,
3)], Point(12.5, 3)), 17.22704371324152)
 Individual(Phenotype(Point(2.5, 2.5), Point[Point(2.5, 2.5), Point(3.4125, 2.7666666666666666), Point(4.625, 2.3000000000000003), Point(5.276936463360386, 3.398948791953753), Point(10, 7.5)], Point(10, 7.5)), 12.060208457332184)
 Individual(Phenotype(Point(5, 5), Point[Point(5, 5), Point(5.3125, 5.1), Point(5.625, 4.8), Point(6.5375, 4.8999999999999995), Point(6.949999999999999, 4.999999999999999), Point(7.862499999999999, 4.966666666666666), Point(8.674999999999999, 4.999999999999999), Point(12.5, 7.5)], Point(12.5, 7.5)), 8.289795563638675)
]
# Out:
# 4-element Array{Individual,1}:
#  Individual(Phenotype(Point(0, 7.5), Point[Point(0, 7.5), Point(2.2416666666666667, 7.433333333333334), Point(2.7625, 7.4), Point(3.2833333333333337, 7.5), Point(4.204166666666667, 7.333333333333333), Point(5.825, 7.3), Point(10.538890680627116, 19.364065470035655), Point(12.5, 10)], Point(12.5, 10)), 70.37475581977573)
#  Individual(Phenotype(Point(0, 2.5), Point[Point(0, 2.5), Point(8.125, 2.5), Point(10.080648092947305, 2.5989547397963246), Point(12.5, 3)], Point(12.5, 3)), 17.22704371324152)
#  Individual(Phenotype(Point(2.5, 2.5), Point[Point(2.5, 2.5), Point(3.4125, 2.7666666666666666), Point(4.625, 2.3000000000000003), Point(5.276936463360386, 3.398948791953753), Point(10, 7.5)], Point(10, 7.5)), 12.060208457332184)
# ...

# %%
include("plottingUtils.jl")
plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/jIs2V/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
include("parallelCGA.jl")
include("quickstart.jl")
include("plottingUtils.jl")
# Out:
# WARNING: using Plots.BezierCurve in module Main conflicts with an existing identifier.
# plot_generation_gif (generic function with 1 method)

# %% [markdown]
# Here I am comparing the two bezInt methods, new checks all combinations of each subcurve, old only subdivides the curve with the largest diameter

# %%
P_new = [Individual(Phenotype(Point(0, 2), Point[Point(0, 2), Point(0.0, 0.0), Point(15, 6.8)], Point(15, 6.8)), 17.109325599460085)
 Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(7.0875, 4), Point(15.1, 18.0), Point(15.1, 4)], Point(15.1, 4)), 28.58975180038798)
 Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(0.0, 0.0), Point(0.0, 0.0), Point(1.9, 1.0), Point(2.9, 1.4), Point(4.6, 1.7), Point(7.2, 3.2), Point(12, 10)], Point(12, 10)), 24.37768118089833)
]
plot_generation_gif(road,P_new)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
P_old = [Individual(Phenotype(Point(0, 2), Point[Point(0, 2), Point(0.0, 5.055728482688453), Point(4.612500000000001, 1.8599999999999999), Point(6.250000000000001, 1.98), Point(8.241359981697975, 5.567375558505024), Point(15, 6.8)], Point(15, 6.8)), 24.594356787114474)
 Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(1.955, 4), Point(3.91, 4), Point(5.265000000000001, 4), Point(8.547171509124542, 7.944015132516796), Point(9.375, 4.0), Point(15.1, 4)], Point(15.1, 4)), 19.55258219107357)
 Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(8.546016322611466, 0.0), Point(8.689166451936769, 0.0), Point(12, 10)],
Point(12, 10)), 17.681620744601936)
]
plot_generation_gif(road,[P_old[1],P_old[3]])
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
collisionDetection(P_old[1].phenotype.genotype,P_old[3].phenotype.genotype)
# Out:
# "Detecting Collisions parallel" = "Detecting Collisions parallel"
# Found intersection (true, (Point[Point(0, 2), Point(0.0, 2.190983030168028), Point(0.018017578125000003, 2.357546306565053), Point(0.05220031738281251, 2.502025567825856), Point(0.10086237121554106, 2.626612882871286), Point(0.1624750871645235, 2.733359933230784)], Point[Point(0, 1), Point(0.5341260201632166, 0.9375), Point(1.0354283442589092, 0.87890625), Point(1.5067318135009506, 0.826416015625)]))
# Intersection
# abs(bezLength(c1_to_intersect) - bezLength(c2_to_intersect)) < 3.5 = true
# true

# %%
P = [
     Individual(Phenotype(Point(0, 2), Point[Point(0, 2), Point(0.0, 17.030032303156897), Point(1.325, 2.22), Point(3.25, 2.14), Point(4.8,
1.98), Point(6.949999999999999, 2.42), Point(9.364254038876465, 11.057485615235137), Point(15, 6.8)], Point(15, 6.8)), 89.80565284669933)
 Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(0.0, 0.0), Point(14.425532446253975, 0.0), Point(15.1, 4)], Point(15.1, 4)), 20.781948123218797)
 Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(2.1, 0.7), Point(3.7, 0.19999999999999996), Point(5.1, 1.1), Point(6.3, 2.0), Point(12.0, 0.0), Point(12, 10)], Point(12, 10)), 21.001989620181426)


]
# Out:
# 3-element Array{Individual,1}:
#  Individual(Phenotype(Point(0, 2), Point[Point(0, 2), Point(0.0, 17.030032303156897), Point(1.325, 2.22), Point(3.25, 2.14), Point(4.8, 1.98), Point(6.949999999999999, 2.42), Point(9.364254038876465, 11.057485615235137), Point(15, 6.8)], Point(15, 6.8)), 89.80565284669933)
#  Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(0.0, 0.0), Point(14.425532446253975, 0.0), Point(15.1, 4)], Point(15.1, 4)), 20.781948123218797)
#  Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(2.1, 0.7), Point(3.7, 0.19999999999999996), Point(5.1, 1.1), Point(6.3, 2.0), Point(12.0, 0.0), Point(12, 10)], Point(12, 10)), 21.001989620181426)

# %%
plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
infeasible_distance(road,P[1].phenotype.genotype)
# Out:
# 1.0229657087882296

# %%
P =[
    Individual(Phenotype(Point(0, 2), Point[Point(0, 2), Point(0.0, 0.0), Point(0.0, 0.0), Point(1.2066696737211409, 0.0), Point(4.9804229897249295, 0.0), Point(12.421875272569359, 4.317751288944928), Point(15.0, 18.0), Point(15, 6.8)], Point(15, 6.8)), 42.57132450251116)
 Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(9.366358245176537, 0.0), Point(12.368898975924722, 0.0), Point(14.165413827035236, 18.0), Point(15.1, 3.3872592013914193), Point(15.1, 4)], Point(15.1, 4)), 96.1599826305187)
 Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(0.0, 0.0), Point(0.0, 0.0), Point(0.8883441762226796, 3.2524498869849703), Point(3.8198628141664592, 0.0), Point(7.5804114940119565, 0.7540644965335174), Point(12, 10)], Point(12, 10)), 30.617944322287617)
]
# Out:
# 3-element Array{Individual,1}:
#  Individual(Phenotype(Point(0, 2), Point[Point(0, 2), Point(0.0, 0.0), Point(0.0, 0.0), Point(1.2066696737211409, 0.0), Point(4.9804229897249295, 0.0), Point(12.421875272569359, 4.317751288944928), Point(15.0, 18.0), Point(15, 6.8)], Point(15, 6.8)), 42.57132450251116)
#  Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(9.366358245176537, 0.0), Point(12.368898975924722, 0.0), Point(14.165413827035236, 18.0), Point(15.1, 3.3872592013914193), Point(15.1, 4)], Point(15.1, 4)), 96.1599826305187)
#  Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(0.0, 0.0), Point(0.0, 0.0), Point(0.8883441762226796, 3.2524498869849703), Point(3.8198628141664592, 0.0), Point(7.5804114940119565, 0.7540644965335174), Point(12, 10)], Point(12, 10)), 30.617944322287617)

# %%
plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
@show infeasible_distance(road,P[2].phenotype.genotype)
@show high_proximity_distance(road,P[2].phenotype.genotype)
# Out:
# infeasible_distance(road, (P[2]).phenotype.genotype) = 1.0471962899815166
# high_proximity_distance(road, (P[2]).phenotype.genotype) = 0
# 0

# %%
P = [
    Individual(Phenotype(Point(0, 2), Point[Point(0, 2), Point(0.0, 0.0), Point(4.475, 1.7666666666666666), Point(15, 6.8)], Point(15, 6.8)), 21.756644307894643)
 Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(0.0, 6.974493537672236), Point(5.787733898672924, 18.0), Point(10.875, 3.8333333333333335), Point(15.1, 4)], Point(15.1, 4)), 26.8822741382061)
 Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(2.2, 2.0833333333333335), Point(4.0, 1.166666666666667), Point(5.6, 1.2500000000000002), Point(6.145744618907339, 9.398467080189802), Point(6.699999999999999, 1.7500000000000002), Point(12.0, 18.0), Point(12, 10)], Point(12, 10)), 100.09784744196435)

]
# Out:
# 3-element Array{Individual,1}:
#  Individual(Phenotype(Point(0, 2), Point[Point(0, 2), Point(0.0, 0.0), Point(4.475, 1.7666666666666666), Point(15, 6.8)], Point(15, 6.8)), 21.756644307894643)
#  Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(0.0, 6.974493537672236), Point(5.787733898672924, 18.0), Point(10.875, 3.8333333333333335), Point(15.1, 4)], Point(15.1, 4)), 26.8822741382061)
#  Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(2.2, 2.0833333333333335), Point(4.0, 1.166666666666667), Point(5.6, 1.2500000000000002), Point(6.145744618907339, 9.398467080189802), Point(6.699999999999999, 1.7500000000000002), Point(12.0, 18.0), Point(12, 10)], Point(12, 10)), 100.09784744196435)

# %%
plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
b1(x) = tan(x/20)

b2(x) = tan((x/20))+4
road = Road(b1,b2, [Rectangle(2,1,Point(10,1))])
draw_road(road,0,20)

# %%
starts = [Point(0,1),Point(0,3)]
goals = [Point(20,5), Point(20,3)]
P = [Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(0.0, 3.401633127667389), Point(8.1, 1.3333333333333333), Point(20, 5)], Point(20, 5)), 38.75539606096389)
 Individual(Phenotype(Point(0, 3), Point[Point(0, 3), Point(11.7, 3.0), Point(20.0, 7.1680557934911775), Point(20, 3)], Point(20, 3)), 207.43016979361465)
]

plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
P = [
     Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(4.55, 1.0), Point(8.0, 0.8333333333333334), Point(11.15, 0.5), Point(12.400000000000002, 1.1666666666666665), Point(14.7,
0.75), Point(20.0, 1.1680557934911766), Point(20, 5)], Point(20, 5)), 32.656037409559374)
 Individual(Phenotype(Point(0, 3), Point[Point(0, 3), Point(1.65, 3.0), Point(3.5, 3.0), Point(14.714814347949575, 5.5171922299323235), Point(20.0, 1.1680557934911766), Point(20, 3)], Point(20, 3)), 22.621682233411892)
]
plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
b1(x) = tan(x/20)*3

b2(x) = tan((x/20))*3+4
road = Road(b1,b2, [Rectangle(2,1,Point(10,1))])
draw_road(road,0,20)

# %%
starts = [Point(0,1), Point(0,3)]
goals = [Point(15,4),Point(20,6)]

# %%
P =[
Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(0.0, 2.096092034874163), Point(1.6375, 0.8333333333333334), Point(2.4186542572660503, 6.091734140254988), Point(7.6125, 1.0), Point(15, 4)], Point(15, 4)), 26.82216777827364)
 Individual(Phenotype(Point(0, 3), Point[Point(0, 3), Point(17.56254375705059, 3.50416738047353), Point(20, 6)], Point(20, 6)), 20.641066733734316)    
]
plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
P = [
    Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(0.0, 2.096092034874163), Point(6.954636578762885, 4.183559056145221), Point(7.3, 0.7000000000000001), Point(13.120264774496375, 3.0885032591586588), Point(15.0, 8.096092034874163), Point(15, 4)], Point(15, 4)), 24.62627137667704)
 Individual(Phenotype(Point(0, 3), Point[Point(0, 3), Point(1.8378085070545769, 4.606519118161985), Point(1.86231409349308, 3.50416738047353), Point(20.0, 3.50416738047353), Point(20.0, 3.50416738047353), Point(20, 6)], Point(20, 6)), 113.61757928319)

]

plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
P = [
     Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(0.0, 2.096092034874163), Point(15.0, 8.096092034874163), Point(15.0, 2.096092034874163), Point(15, 4)], Point(15, 4)), 21.869349127861792)
 Individual(Phenotype(Point(0, 3), Point[Point(0, 3), Point(0.0, 8.014127198970233), Point(6.15, 3.1999999999999997), Point(6.203238922036415, 3.50416738047353), Point(6.33440145616461, 5.852096698758423), Point(20, 6)], Point(20, 6)), 173.80300213749203)

]

plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
infeasible_distance(road, P[2].phenotype.genotype)
# Out:
# 4.906753662893168

# %%
P = [Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(0.0, 2.096092034874163), Point(0.0, 5.151450677785128), Point(0.0, 2.096092034874163), Point(0.0, 3.9986030326703377), Point(15, 4)], Point(15, 4)), 21.59153128561014)
 Individual(Phenotype(Point(0, 3), Point[Point(0, 3), Point(0.0, 3.50416738047353), Point(0.0, 2.3), Point(0.0, 3.50416738047353), Point(0.0, 3.50416738047353), Point(6.62950130873762, 3.50416738047353), Point(15.281012132527714, 5.174606814162506), Point(20, 6)], Point(20, 6)), 22.495002181879766)
]
plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/src/anim1.gif")

# %%
collisionDetection()
