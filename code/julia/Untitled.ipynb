# %%
include("src/bezier.jl")
include("src/plottingUtils.jl")
# Out:
# plot_generation_gif (generic function with 1 method)

# %%
c = BezierCurve([Point(0,0),Point(2,5),Point(5,4)])
plt = plot_curve(c,100)
for p in c
    plot!(plt,[(p.x,p.y)],seriestype=:scatter)
end
plt

# %%
include("src/bezier.jl")

@show (c1,c2) = deCasteljau(c,0.5)
p = plot_curve(c,100)
ps_x, ps_y = [], []
for x in range(0, 1, step = 1 / 100)
    C = c1(x)
    append!(ps_x, C.x)
    append!(ps_y, C.y)
end
p = plot!(p,(ps_x, ps_y),linewidth=3,legend=false)
for cp in c1
    plot!(p,(cp.x,cp.y),seriestype=:scatter)
end

ps_x, ps_y = [], []
for x in range(0, 1, step = 1 / 100)
    C = c2(x)
    append!(ps_x, C.x)
    append!(ps_y, C.y)
end
p = plot!(p,(ps_x, ps_y),linewidth=4)
p
# Out:
# (c1, c2) = deCasteljau(c, 0.5) = (Point[Point(0, 0), Point(1.0, 2.5), Point(2.25, 3.5)], Point[Point(5, 4), Point(3.5, 4.5), Point(2.25, 3.5)])

# %%
plot_curve!(p,2,[c(0.5),c(0.75),c(1)],100)

# %%
plot_curve(c1,200)

# %%
plt3 = plot_curve!(plt,3,c2,100)

# %%
c(0.5)
# Out:
# Point(2.0, 3.5)

# %%
n =3 
r = []
for j in 1:n
    for i in 0:n-j
        @show (j,i)
        append!(r,[c[1:j](1-(0.5*i))])
    end
end
r = r[4:end]
@show r
plot_curve(BezierCurve(r),100)
# Out:
# (j, i) = (1, 0)
# (j, i) = (1, 1)
# (j, i) = (1, 2)
# (j, i) = (2, 0)
# (j, i) = (2, 1)
# (j, i) = (3, 0)
# r = Any[Point(2.0, 5.0), Point(1.0, 2.5), Point(5.0, 4.0)]

# %%
t = 0.6 
c = BezierCurve([Point(0,0),Point(2,5),Point(5,4)])
c1 = [ c[1:i](t) for i in 1:length(c)]
c2 = [ c[i:length(c)](1-t) for i in length(c):-1:1]
# Out:
# 3-element Array{Point,1}:
#  Point(5, 4)
#  Point(3.2, 4.6)
#  Point(1.7600000000000002, 3.04)

# %%
p = plot_curve(c,100)
ps_x, ps_y = [], []
for x in range(0, 1, step = 1 / 100)
    C = c1(x)
    append!(ps_x, C.x)
    append!(ps_y, C.y)
end
p = plot!(p,(ps_x, ps_y),linewidth=3,legend=false)

# %%
p = plot_curve(c,100)
ps_x, ps_y = [], []
for x in range(0, 1, step = 1 / 100)
    C = c2(x)
    append!(ps_x, C.x)
    append!(ps_y, C.y)
end
p = plot!(p,(ps_x, ps_y),linewidth=3,legend=false)

# %%
include("src/quickstart.jl")
P = [ Individual(Phenotype(Point(0, 2), Point[Point(0, 2), Point(0.0, 5.568853370258944), Point(15, 6.8)], Point(15, 6.8)), 85.92144582958589)
 Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(15.1, 9.478160830213575), Point(15.1, 0.0), Point(15.1, 4)], Point(15.1, 4)), 23.476889803734796)
 Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(0.0, 0.0), Point(2.65, 0.09999999999999998), Point(4.4, 0.19999999999999998), Point(5.65, 0.09999999999999998), Point(12,
10)], Point(12, 10)), 23.62635219056923)
]
plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/anim1.gif")

# %%
P = [
     Individual(Phenotype(Point(0, 2), Point[Point(0, 2), Point(0.0, 0.0), Point(0.0, 6.742567673480388), Point(6.800000000000001, 2.6533333333333333), Point(9.65, 2.8), Point(15, 6.8)], Point(15, 6.8)), 31.340884046177216)
 Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(0.0, 18.0), Point(0.0, 9.908404466661343), Point(3.41, 3.8666666666666667), Point(7.52, 3.8), Point(8.774999999999999, 3.8666666666666667), Point(15.1, 4)], Point(15.1, 4)), 32.85017346708262)
 Individual(Phenotype(Point(0, 1), Point[Point(0, 1), Point(2.4, 1.6), Point(5.800000000000001, 0.6), Point(7.200000000000001, 0.26666666666666666), Point(7.4, 2.2), Point(8.6, 0.7999999999999999), Point(9.299999999999999, 1.1333333333333333), Point(12, 10)], Point(12, 10)), 23.525254492402357)
]
plot_generation_gif(road,P)
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/julia/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/6EMd6/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/julia/anim1.gif")
