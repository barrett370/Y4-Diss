# %%
using Pkg
Pkg.add("WebIO")
# Out:
#    Updating registry at `~/.julia/registries/General`
#   Resolving package versions...
#   Installed MbedTLS ──────────── v1.0.3
#   Installed OrderedCollections ─ v1.3.2
#   Installed Requires ─────────── v1.1.2
#   Installed JLLWrappers ──────── v1.1.3
# Updating `~/git-clones/Y4-Diss/code/classical/julia/Project.toml`
#   [0f1e0344] + WebIO v0.8.15
# Updating `~/git-clones/Y4-Diss/code/classical/julia/Manifest.toml`
#   [56f22d72] + Artifacts v1.3.0
#   [bf4720bc] + AssetRegistry v0.1.0
#   [3da002f7] + ColorTypes v0.10.9
#   [5ae59095] + Colors v0.12.4
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [de31a74c] + FunctionalCollections v0.5.0
#   [cd3eb016] + HTTP v0.8.19
#   [83e8ac13] + IniFile v0.5.0
#   [692b3bcd] + JLLWrappers v1.1.3
#   [682c06a0] + JSON v0.21.1
#   [739be429] + MbedTLS v1.0.3
#   [c8ffd9c3] + MbedTLS_jll v2.16.8+1
#   [510215fc] + Observables v0.3.2
#   [bac558e1] + OrderedCollections v1.3.2
#   [69de0a69] + Parsers v1.0.15
#   [fa939f87] + Pidfile v1.2.0
#   [189a3867] + Reexport v0.2.0
#   [ae029012] + Requires v1.1.2
#   [0f1e0344] + WebIO v0.8.15
#   [104b5d7c] + WebSockets v1.5.2
#   [cc8bc4a8] + Widgets v0.6.2
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [8ba89e20] + Distributed
#   [7b1f6079] + FileWatching
#   [b77e0a4c] + InteractiveUtils
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [44cfe95a] + Pkg
#   [de0858da] + Printf
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA
#   [9e88b42a] + Serialization
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode

# %%
using WebIO
using IJulia
include("GA.jl")
include("plottingUtils.jl")
include("roadNetwork.jl")

# %%
boundary1(x) = 0
boundary2(x) = 13
# boundary1(x) = sin(x+12)+4
# boundary2(x) = sin(x+4)+12
o1 = Circle(1,Point(5,10))
o2 = Circle(1.2,Point(10,7))
o3 = Circle(0.8,Point(7,6))
o4 = Circle(0.8,Point(12,8))
# o2 = Rectangle(3,2,Point(10,7))
start_point = Point(0,10)
goal_point = Point(19,5.2)

road = Road(boundary1,boundary2,[o1,o2,o3,o4])
# road = Road(boundary1,boundary2,[])
# Out:
# Road(boundary1, boundary2, Obstacle[Circle(1, Point(5, 10)), Circle(1.2, Point(10, 7)), Circle(0.8, Point(7, 6)), Circle(0.8, Point(12, 8))])

# %%
gr()

draw_road(road,0,20)

# %%
circle = Circle(1,Point(5,10))
test_curve = BezierCurve([Point(2,9),Point(6,11)])
test_curve = BezierCurve([Point(0, 10), Point(9.792786584297819, 12.404595735445575), Point(19, 9)])
# Out:
# 3-element Array{Point,1}:
#  Point(0, 10)
#  Point(9.792786584297819, 12.404595735445575)
#  Point(19, 9)

# %%
plt = plot(get_circle(circle))
plot!(plt,get_curve(test_curve))

# %%
curve_values = get_curve(test_curve)
i = findall(x -> x==4,curve_values[1])
@show i
curve_values[2][i]
# Out:
# i = Int64[]
# Any[]

# %%
circle_values = get_circle(circle)
is = findall(x -> round(x,digits=2) == 4.00,circle_values[1])
# filter(x -> x<4.1,circle_values[1])
# Out:
# 16-element Array{Int64,1}:
#  243
#  244
#  245
#  246
#  247
#  248
#  249
#  250
#  251
#  252
#  253
#  254
#  255
#  256
#  257
#  258

# %%
circ_intersects = []
for i in is
    if round(circle_values[2][i],digits=1) == curve_values[2][251]
        append!(circ_intersects,[i])
    end
end
circ_intersects
# Out:
# Any[]

# %%
intersects = []
for i in 1:length(curve_values[1])
    x = curve_values[1][i]
    y = curve_values[2][i]
    potential_intersect_circle_is = findall(cx -> round(cx,digits=1)==round(x,digits=1),circle_values[1])
    for j in potential_intersect_circle_is
        if round(y,digits=1) == round(circle_values[2][j],digits=1)
            append!(intersects,[(x,y)])
        end
    end
end
@show intersects

infeasbile_d = √((intersects[1][1]-intersects[end][1])^2 + (intersects[1][2] - intersects[end][2])^2)
# Out:
# intersects = Any[(4.280484355731011, 10.776857256404922), (4.280484355731011, 10.776857256404922), (4.319137855387164, 10.781340314086437), (4.319137855387164, 10.781340314086437), (4.357786670457968, 10.785776898236183), (4.357786670457968, 10.785776898236183), (4.357786670457968, 10.785776898236183), (4.357786670457968, 10.785776898236183), (4.357786670457968, 10.785776898236183), (4.357786670457968, 10.785776898236183), (4.357786670457968, 10.785776898236183), (4.357786670457968, 10.785776898236183), (4.357786670457968, 10.785776898236183), (4.396430800943424, 10.790167008854164), (4.396430800943424, 10.790167008854164), (4.396430800943424, 10.790167008854164), (4.396430800943424, 10.790167008854164), (4.396430800943424, 10.790167008854164), (4.396430800943424, 10.790167008854164), (4.396430800943424, 10.790167008854164), (4.396430800943424, 10.790167008854164), (4.396430800943424, 10.790167008854164), (4.43507024684353, 10.794510645940377), (4.43507024684353, 10.794510645940377), (4.43507024684353, 10.794510645940377), (4.43507024684353, 10.794510645940377), (4.43507024684353, 10.794510645940377), (4.43507024684353, 10.794510645940377), (4.43507024684353, 10.794510645940377), (4.43507024684353, 10.794510645940377), (4.43507024684353, 10.794510645940377), (4.473705008158287, 10.798807809494825), (4.473705008158287, 10.798807809494825), (4.473705008158287, 10.798807809494825), (4.512335084887696, 10.803058499517503), (4.512335084887696, 10.803058499517503), (4.512335084887696, 10.803058499517503), (5.283952856552634, 10.878312858299982), (5.283952856552634, 10.878312858299982), (5.283952856552634, 10.878312858299982), (5.322484556989719, 10.881587604155552), (5.322484556989719, 10.881587604155552), (5.322484556989719, 10.881587604155552), (5.361011572841456, 10.884815876479353), (5.361011572841456, 10.884815876479353), (5.361011572841456, 10.884815876479353), (5.361011572841456, 10.884815876479353), (5.361011572841456, 10.884815876479353), (5.361011572841456, 10.884815876479353), (5.361011572841456, 10.884815876479353), (5.361011572841456, 10.884815876479353), (5.361011572841456, 10.884815876479353), (5.399533904107843, 10.88799767527139), (5.399533904107843, 10.88799767527139), (5.399533904107843, 10.88799767527139), (5.399533904107843, 10.88799767527139), (5.399533904107843, 10.88799767527139), (5.399533904107843, 10.88799767527139), (5.399533904107843, 10.88799767527139), (5.399533904107843, 10.88799767527139), (5.399533904107843, 10.88799767527139), (5.438051550788881, 10.891133000531656), (5.438051550788881, 10.891133000531656), (5.438051550788881, 10.891133000531656), (5.438051550788881, 10.891133000531656), (5.438051550788881, 10.891133000531656), (5.438051550788881, 10.891133000531656), (5.438051550788881, 10.891133000531656), (5.438051550788881, 10.891133000531656), (5.438051550788881, 10.891133000531656), (5.47656451288457, 10.894221852260156), (5.47656451288457, 10.894221852260156), (5.47656451288457, 10.894221852260156), (5.47656451288457, 10.894221852260156), (5.47656451288457, 10.894221852260156), (5.47656451288457, 10.894221852260156), (5.47656451288457, 10.894221852260156), (5.51507279039491, 10.89726423045689), (5.51507279039491, 10.89726423045689), (5.51507279039491, 10.89726423045689), (5.51507279039491, 10.89726423045689), (5.51507279039491, 10.89726423045689), (5.51507279039491, 10.89726423045689), (5.51507279039491, 10.89726423045689)]
# 1.2404460658997665

# %%
include("GA.jl")
include("roadNetwork.jl")
include("plottingUtils.jl")
P = GA(start_point,goal_point,road,1,20)
# Out:
# 20-element Array{Individual,1}:
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(0.8916666666666667, 5.2), Point(3.3833333333333333, 4.96), Point(4.675, 4.72), Point(7.266666666666667, 4.68), Point(10.058333333333334, 4.64), Point(12.35, 4.449999999999999), Point(19, 5.2)], Point(19, 5.2)), 22.301870148718557)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(2.7916666666666665, 5.2), Point(3.683333333333333, 5.01), Point(5.375, 4.97), Point(7.866666666666667, 4.779999999999999), Point(10.358333333333334, 4.589999999999999), Point(12.65, 4.699999999999999), Point(19, 5.2)], Point(19, 5.2)), 24.0455383747371)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.55, 5.2), Point(4.0, 5.2), Point(5.15, 5.01), Point(6.1000000000000005, 4.97), Point(8.850000000000001, 4.7299999999999995), Point(19, 5.2)], Point(19, 5.2)), 25.282046891732964)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.65, 5.2), Point(4.3, 5.0600000000000005), Point(5.25, 5.12), Point(6.6, 5.08), Point(8.649999999999999, 4.84), Point(19, 5.2)], Point(19, 5.2)), 25.755173299894455)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)

# %%
plotGeneration!(draw_road(road,0,20),[P[1],P[6]],road)

# map(i->isFeasible(road,i),P)

# %%
[P[1],P[6]]
# Out:
# 2-element Array{Individual,1}:
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(0.8916666666666667, 5.2), Point(3.3833333333333333, 4.96), Point(4.675, 4.72), Point(7.266666666666667, 4.68), Point(10.058333333333334, 4.64), Point(12.35, 4.449999999999999), Point(19, 5.2)], Point(19, 5.2)), 22.301870148718557)
#  Individual(Phenotype(Point(0, 10), Point[Point(0, 10), Point(1.0916666666666666, 5.2), Point(2.283333333333333, 5.01), Point(4.775, 5.12), Point(7.166666666666667, 5.08), Point(9.558333333333334, 5.19), Point(12.25, 5.2), Point(19, 5.2)], Point(19, 5.2)), 26.52925399516677)

# %%
P_valid = filter(i -> infeasible_distance(road,i.phenotype.genotype)==0,P)
plotGeneration!(draw_road(road,0,20),P_valid,road)

# %% [markdown]
# This is what the generated routes look like after all infeasible and uncomfortably close routes are filtered out

# %%
plotGeneration!(draw_road(road,0,20),filter(i->high_proximity_distance(road,i.phenotype.genotype)==0,filter(i -> infeasible_distance(road,i.phenotype.genotype)==0,P)))
# Out:
# UndefVarError: P not defined
#
# Stacktrace:
#  [1] top-level scope at In[18]:1

# %%
best = P[1].fitness
# Out:
# UndefVarError: P not defined
#
# Stacktrace:
#  [1] top-level scope at In[19]:1

# %%
optimal = √((start_point.x - goal_point.x)^2 + (start_point.y - goal_point.y)^2)
# Out:
# 19.596938536414303

# %%
(best/optimal-1)*100
# Out:
# UndefVarError: best not defined
#
# Stacktrace:
#  [1] top-level scope at In[21]:1

# %%
filter(i-> high_proximity_distance(road,i.phenotype.genotype)==0 ∘ i->infeasible_distance(road,i.phenotype.genotype)==0,P)
# Out:
# UndefVarError: P not defined
#
# Stacktrace:
#  [1] top-level scope at In[22]:1

# %%
function plotObstacles(road)
    plt = plot()
    for o in road.obstacles
        plot!(plt,get_circle(o), seriestype=[:shape],legend=false )
    end
    plt
end
# Out:
# plotObstacles (generic function with 1 method)

# %%
include("plottingUtils.jl")
# plt =plotObstacles(road)
# plotGeneration!(plt,P)
# Out:
# plot_control_points! (generic function with 1 method)

# %%
include("roadNetwork.jl")
include("utils.jl")

c = BezierCircle()
# x = BezierCurve([Point(0,1)])
# Out:
# UndefVarError: BezierCircle not defined
#
# Stacktrace:
#  [1] top-level scope at In[25]:4

# %%
circ = Circle(1,Point(0,0))
# Out:
# Circle(1, Point(0, 0))

# %%
circ(π)
# c(0.5)
# Out:
# (-1.0, 1.2246467991473532e-16)

# %%
plot_curve(c,100)
# Out:
# UndefVarError: c not defined
#
# Stacktrace:
#  [1] top-level scope at In[28]:1

# %%
c = (4/3)*(√(2)-1)
c1 = BezierCurve([Point(0,1),Point(c,1),Point(1,c),Point(1,0)])
c2 = BezierCurve([Point(1,0),Point(1,-c),Point(c,-1),Point(0,-1)])
c3 = BezierCurve([Point(0,-1),Point(-c,-1),Point(-1,-c),Point(-1,0)])
c4 = BezierCurve([Point(-1,0),Point(-1,c),Point(-c,1),Point(0,1)])
# Out:
# 4-element Array{Point,1}:
#  Point(-1, 0)
#  Point(-1, 0.5522847498307935)
#  Point(-0.5522847498307935, 1)
#  Point(0, 1)

# %%
plt = plot()
plot_curve!(plt,1,c1,100)
plot_curve!(plt,2,c2,100)
plot_curve!(plt,3,c3,100)
plot_curve!(plt,4,c4,100)

# %%
include("FitnessLandscape.jl")
fitness_landscape(road,Fitness,(start_point.x,goal_point.x),(start_point.y,goal_point.y))
# Out:
# could not open file /home/sam/git-clones/Y4-Diss/code/classical/julia/FitnessLandscape.jl
#
# Stacktrace:
#  [1] include(::String) at ./client.jl:457
#  [2] top-level scope at In[31]:1

# %%
xs = Array(range(0,4,step=0.2))
ys = Array(range(2,5,step=0.2))
# Out:
# 16-element Array{Float64,1}:
#  2.0
#  2.2
#  2.4
#  2.6
#  2.8
#  3.0
#  3.2
#  3.4
#  3.6
#  3.8
#  4.0
#  4.2
#  4.4
#  4.6
#  4.8
#  5.0
