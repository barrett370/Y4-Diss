# %%
include("GA.jl")
include("quickstart.jl");
include("plottingUtils.jl")
# Out:
# plot_generation_gif (generic function with 1 method)

# %%
P = generatePopulation(5, starts[1], goals[1],road)
map(p -> p.fitness = Fitness(road,p), P)
P
# Out:
# 5-element Array{Individual,1}:
#  Individual(Phenotype(Point(10, 4), Point[Point(10, 4), Point(11.325, 4.04), Point(12.75, 3.88), Point(15, 4.8)], Point(15, 4.8)), 5.139666743102663)
#  Individual(Phenotype(Point(10, 4), Point[Point(10, 4), Point(10.708333333333334, 4.04), Point(11.216666666666667, 4.08), Point(11.925, 3.92), Point(12.533333333333333, 3.76), Point(13.341666666666667, 3.5999999999999996), Point(13.95, 3.4399999999999995), Point(15, 4.8)], Point(15, 4.8)), 5.594179364501914)
#  Individual(Phenotype(Point(10, 4), Point[Point(10, 4), Point(10.608333333333333, 3.84), Point(11.216666666666665, 3.6799999999999997), Point(11.624999999999998, 3.5199999999999996), Point(12.133333333333331, 3.5599999999999996), Point(12.941666666666665, 3.3999999999999995), Point(13.549999999999997, 3.2399999999999993), Point(15, 4.8)], Point(15, 4.8)), 8.274231536030653)
# ...

# %%
include("geneticOperators.jl")
new_P = rank_selection(P)
# Out:
# Using linear ranking
# 5-element Array{Individual,1}:
#  Individual(Phenotype(Point(10, 4), Point[Point(10, 4), Point(10.708333333333334, 4.04), Point(11.216666666666667, 4.08), Point(11.925, 3.92), Point(12.533333333333333, 3.76), Point(13.341666666666667, 3.5999999999999996), Point(13.95, 3.4399999999999995), Point(15, 4.8)], Point(15, 4.8)), 5.594179364501914)
#  Individual(Phenotype(Point(10, 4), Point[Point(10, 4), Point(11.65, 4.04), Point(15, 4.8)], Point(15, 4.8)), 5.0746038503671524)
#  Individual(Phenotype(Point(10, 4), Point[Point(10, 4), Point(11.65, 4.04), Point(15, 4.8)], Point(15, 4.8)), 5.0746038503671524)
#  Individual(Phenotype(Point(10, 4), Point[Point(10, 4), Point(10.708333333333334, 4.04), Point(11.216666666666667, 4.08), Point(11.925, 3.92), Point(12.533333333333333, 3.76), Point(13.341666666666667, 3.5999999999999996), Point(13.95, 3.4399999999999995), Point(15, 4.8)], Point(15, 4.8)), 5.594179364501914)
# ...

# %%
P == new_P
# Out:
# false

# %%
include("GA.jl")
@time P_roulette = GA(starts[2],goals[2],road,n_gens=5, n=10)
# Out:
#   3.067737 seconds (101.26 M allocations: 2.351 GiB, 10.05% gc time)
# 10-element Array{Individual,1}:
#  Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(13.375, 4), Point(15.1, 4)], Point(15.1, 4)), 15.24029025609498)
#  Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(3.9875, 4), Point(6.576428893073964, 4.968350648769523), Point(15.1, 4)], Point(15.1, 4)), 18.412823496995266)
#  Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(6.761650789345456, 9.438637803101448), Point(10.57592531657006, 4.963809297054556), Point(13.219697100408057, 4.125341057891674), Point(15.1, 3.9), Point(15.1, 4)], Point(15.1, 4)), 23.914269169305882)
#  Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(6.238502413323006, 4.052851471101011), Point(9.066780499649767, 9.602715134999707), Point(11.820839277249453, 4.357592540088307), Point(14.457023804486246, 4.599695483193258), Point(15.1, 4)], Point(15.1, 4)), 31.647073956937124)
# ...

# %%
@time P_ranked = GA(starts[2],goals[2],road,n_gens=5, n=10, selection_method="ranked")
# Out:
#   2.766529 seconds (110.36 M allocations: 2.599 GiB, 12.37% gc time)
# 10-element Array{Individual,1}:
#  Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(9.182910560556895, 4.119058226982859), Point(15.1, 4)], Point(15.1, 4)), 15.261865091739441)
#  Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(3.595480161560619, 4.285708643893226), Point(5.1572640410958535, 5.446866594088002), Point(13.543353585681993, 4.284673064075143), Point(15.1, 3.9), Point(15.1, 4)], Point(15.1, 4)), 15.851319789218588)
#  Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(1.2058091440430965, 4.930667570882582), Point(12.891030801842309, 5.1270406094544025), Point(13.543353585681993, 4.284673064075143), Point(15.1, 3.9), Point(15.1, 4), Point(15.1, 4)], Point(15.1, 4)), 15.858531861427648)
#  Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(8.266046424615901, -2.2768131227252155), Point(15.1, 4)], Point(15.1, 4)), 18.104261987814095)
# ...

# %%
include("plottingUtils.jl")
gif_ranked = plot_generation_gif(road,P_ranked[1:5])
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/classical/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/jIs2V/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/classical/julia/src/anim1.gif")

# %%
gif_roulette = plot_generation_gif(road,P_roulette[1:5])
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/classical/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/jIs2V/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/classical/julia/src/anim1.gif")

# %%
plt_ranked = plot(title="ranked",xlims=[0,20],ylims=[0,10])
plotGeneration!(plt_ranked,P_ranked,road)
plt_roulette = plot(title="roulette",xlims=[0,20],ylims=[0,10])
plotGeneration!(plt_roulette, P_roulette,road)
plot(plt_ranked,plt_roulette,layout=2)

# %%
include("GA.jl")
P_roulette = CGA(starts,goals,road,n_gens=2, n=5, selection_method="roulette")
# Out:
# (start, goal) = (Point(10, 4), Point(15, 4.8))
# (start, goal) = (Point(0, 6), Point(15.1, 4))
# Testing fitness of Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(3.8875, 4), Point(6.475, 3.8), Point(15.1, 4)], Point(15.1, 4)), 0), wrt. Individual(Phenotype(Point(10, 4), Point[Point(10, 4), Point(11.892957646613382, 4.326323371655673), Point(15, 4.8)], Point(15, 4.8)), 5.063707996943663)
# Intersection
# abs(bezLength(i1_to_intersect) - bezLength(i2_to_intersect)) = 16.227661390604084
# Testing fitness of Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(1.2291666666666667, 4), Point(2.2583333333333333, 3.8), Point(3.8875, 3.5999999999999996), Point(5.516666666666667, 3.3999999999999995), Point(7.045833333333333, 3.3999999999999995), Point(8.075, 3.1999999999999993), Point(15.1, 4)], Point(15.1, 4)), 0), wrt. Individual(Phenotype(Point(10, 4), Point[Point(10, 4), Point(11.892957646613382, 4.326323371655673), Point(15, 4.8)], Point(15, 4.8)), 5.063707996943663)
# ...

# %%
P_ranked = CGA(starts,goals,road,n_gens=2, n=5, selection_method="ranked")
# Out:
# (start, goal) = (Point(10, 4), Point(15, 4.8))
# (start, goal) = (Point(0, 6), Point(15.1, 4))
# Testing fitness of Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(2.64375, 4), Point(4.9875, 3.6), Point(7.731249999999999, 3.8000000000000003), Point(11.375, 3.8000000000000003), Point(15.1, 4)], Point(15.1, 4)), 0), wrt. Individual(Phenotype(Point(10, 4), Point[Point(10, 4), Point(12.27713284711459, 4.59308996222794), Point(15, 4.8)], Point(15, 4.8)), 5.073707532550674)
# Intersection
# abs(bezLength(i1_to_intersect) - bezLength(i2_to_intersect)) = 9.900439482170501
# Testing fitness of Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(0.855, 4), Point(1.91, 4), Point(3.965, 3.8), Point(5.72, 3.4), Point(7.175, 3.4), Point(15.1, 4)], Point(15.1, 4)), 0), wrt. Individual(Phenotype(Point(10, 4), Point[Point(10, 4), Point(12.27713284711459, 4.59308996222794), Point(15, 4.8)], Point(15, 4.8)), 5.073707532550674)
# Intersection
# ...

# %%
include("plottingUtils.jl")
gif_ranked = plot_generation_gif(road,P_ranked[1:3])
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/classical/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/jIs2V/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/classical/julia/src/anim1.gif")

# %%
gif_roulette= plot_generation_gif(road,P_roulette[1:3])
# Out:
# ┌ Info: Saved animation to
# │   fn = /home/sam/git-clones/Y4-Diss/code/classical/julia/src/anim1.gif
# └ @ Plots /home/sam/.julia/packages/Plots/jIs2V/src/animation.jl:104
# Plots.AnimatedGif("/home/sam/git-clones/Y4-Diss/code/classical/julia/src/anim1.gif")

# %%
include("GA.jl")

@time P_ranked = CGA(starts[1:2],goals[1:2],road,n_gens=0, n=1, selection_method="ranked")
# Out:
# (start, goal) = (Point(10, 4), Point(15, 4.8))
# (start, goal) = (Point(0, 6), Point(15.1, 4))
# Testing fitness of Individual(Phenotype(Point(0, 6), Point[Point(0, 6), Point(8.375, 4.0), Point(15.1, 4)], Point(15.1, 4)), 0), wrt. Individual(Phenotype(Point(10, 4), Point[Point(10, 4), Point(10.608333333333333, 4.2), Point(11.316666666666666, 3.4000000000000004), Point(11.825, 2.6000000000000005), Point(12.133333333333333, 2.8000000000000007), Point(12.841666666666667, 2.000000000000001), Point(13.65, 1.200000000000001), Point(15, 4.8)], Point(15, 4.8)), 19.60581451364088)
# Intersection
# abs(bezLength(i1_to_intersect) - bezLength(i2_to_intersect)) = 5.8424111754318915
#  23.481694 seconds (751.81 M allocations: 25.191 GiB, 16.81% gc time)
# 2-element Array{Individual,1}:
# ...

# %%
include("GA.jl")
include("quickstart.jl")
@time P_ranked = CGA(starts,goals,road,n_gens=2, n=5, selection_method="ranked")
# Out:
# (start, goal) = (Point(0, 2), Point(15, 6.8))
# (start, goal) = (Point(0, 6), Point(15.1, 4))
# Intersection
# abs(bezLength(i1_to_intersect) - bezLength(i2_to_intersect)) = 5.244277408797277
# Intersection
# abs(bezLength(i1_to_intersect) - bezLength(i2_to_intersect)) = 10.503362143358842
# Intersection
# abs(bezLength(i1_to_intersect) - bezLength(i2_to_intersect)) = 31.280183935181974
# (start, goal) = (Point(0, 1), Point(12, 10))
# Intersection
# abs(bezLength(i1_to_intersect) - bezLength(i2_to_intersect)) = 0.32889878056650845
# Detected collision!
# Intersection
# abs(bezLength(i1_to_intersect) - bezLength(i2_to_intersect)) = 7.589596964374678
# Intersection
# abs(bezLength(i1_to_intersect) - bezLength(i2_to_intersect)) = 1.1178706312449855
# Detected collision!
# Intersection
# abs(bezLength(i1_to_intersect) - bezLength(i2_to_intersect)) = 0.43517709555668693
# Detected collision!
# Intersection
# abs(bezLength(i1_to_intersect) - bezLength(i2_to_intersect)) = 8.883480305866584
# ...

# %%
# times slowdown from intersection detection:

23.481694/0.489051
# Out:
# 48.014816450636026

# %%
include("plottingUtils.jl")
gif_ranked = plot_generation_gif(road,P_ranked)
# Out:
# ┌ Warning: Error requiring IJulia from Plots:
# │ MethodError: no method matching joinpath(::Nothing)
# │ Closest candidates are:
# │   joinpath(!Matched::AbstractString) at path.jl:244
# │   joinpath(!Matched::AbstractString, !Matched::AbstractString...) at path.jl:289
# │ Stacktrace:
# │  [1] _init_ijulia_plotting() at /home/sam/.julia/packages/Plots/jIs2V/src/ijulia.jl:7
# │  [2] top-level scope at /home/sam/.julia/packages/Plots/jIs2V/src/init.jl:75
# │  [3] eval at ./boot.jl:331 [inlined]
# │  [4] eval at /home/sam/.julia/packages/Plots/jIs2V/src/Plots.jl:1 [inlined]
# │  [5] (::Plots.var"#277#310")() at /home/sam/.julia/packages/Requires/vyVBT/src/require.jl:97
# │  [6] err(::Any, ::Module, ::String) at /home/sam/.julia/packages/Requires/vyVBT/src/require.jl:42
# │  [7] (::Plots.var"#276#309")() at /home/sam/.julia/packages/Requires/vyVBT/src/require.jl:96
# │  [8] withpath(::Any, ::String) at /home/sam/.julia/packages/Requires/vyVBT/src/require.jl:32
# ...

# %%
include("bezier.jl")
bezInt(P_ranked[3].phenotype.genotype,P_ranked[2].phenotype.genotype)
# Out:
# creating async tasks
# starting async tasks
# starting async tasks
# starting async tasks
# starting async tasks
